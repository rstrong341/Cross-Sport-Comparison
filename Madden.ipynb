# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

df_2017 = pd.read_csv("data/2017.csv")
df_2018 = pd.read_csv("data/2018.csv")
df_2019 = pd.read_csv("data/2019.csv")
df_2020 = pd.read_csv("data/2020.csv")
df_2021 = pd.read_csv("data/2021.csv")

# %%
df_2017['Name'] = df_2017[['First Name', 'Last Name']].apply(lambda x: ' '.join(x), axis=1)

# %%
df_2017 = df_2017[['Team', 'Name', 'Position', 'Overall', 'Speed',
       'Strength', 'Agility', 'Acceleration', 'Awareness', 'Trucking', 'Ball Carrier Vision', 'Stiff Arm', 'Spin Move',
       'Juke Move', 'Carrying', 'Catching', 'Route Running',
       'Catch In Traffic', 'Release', 'Jumping',
       'Throw Power', 'Throw Accuracy', 'Short Accuracy', 'Middle Accuracy',
       'Deep Accuracy', 'Throw On The Run', 'Play Action',
       'Kick Power', 'Kick Accuracy', 'Impact Blocking', 'Run Blocking',
       'Pass Blocking', 'Kick Return', 'Toughness', 'Stamina', 'Injury']]
df_2017
# Out:
#          Team                   Name Position  Overall  Speed  Strength  \
# 0       49ers         Daniel Kilgore        C       71     60        89
# 1       49ers          Marcus Martin        C       65     64        82
# 2       49ers         Tramaine Brock       CB       81     88        59
# 3       49ers          Kenneth Acker       CB       75     88        50
# 4       49ers         Dontae Johnson       CB       75     89        53
# ...       ...                    ...      ...      ...    ...       ...
# 2358  Vikings          Jarius Wright       WR       75     90        42
# 2359  Vikings        Charles Johnson       WR       74     91        63
# 2360  Vikings  Cordarrelle Patterson       WR       70     92        65
# 2361  Vikings           Adam Thielen       WR       69     87        53
# 2362  Vikings      Moritz Boehringer       WR       62     89        70
#
#       Agility  Acceleration  Awareness  Trucking  ...  Play Action  \
# ...

# %%
df_2018['Name'] = df_2018[['First Name', 'Last Name']].apply(lambda x: ' '.join(x), axis=1)

# %%
df_2018
# Out:
#          Team  teamId  primaryKey   Last Name First Name Position  \
# 0       49ers      15       28454      Zuttah     Jeremy        C
# 1       49ers      15       10960      Barnes        Tim        C
# 2       49ers      15       10679     Kilgore     Daniel        C
# 3       49ers      15       17715    Robinson    Rashard       CB
# 4       49ers      15        2301    Williams     K'Waun       CB
# ...       ...     ...         ...         ...        ...      ...
# 2337  Vikings      31       11265      Wright     Jarius       WR
# 2338  Vikings      31       12775       Adams     Rodney       WR
# 2339  Vikings      31       12657       Coley      Stacy       WR
# 2340  Vikings      31       17842  Boehringer     Moritz       WR
# 2341  Vikings      31       12882     Shelton       R.J.       WR
#
#       Jersey Number  Overall  Speed  Acceleration  ...  Weight  Age  \
# 0                58       82     69            80  ...     300   31
# ...

# %%
df_2018 = df_2018.rename(columns={'Throw Accuracy Short':'Short Accuracy','Throw Accuracy Mid':'Middle Accuracy','Throw Accuracy Deep':'Deep Accuracy','Throw on the Run':'Throw On The Run',})

# %%
df_2018['Run Blocking'] = df_2018['Run Block Strength']+df_2018['Run Block Footwork']
df_2018['Run Blocking'] = df_2018['Run Blocking']/2

# %%
df_2018['Pass Blocking'] = df_2018['Pass Block Strength']+df_2018['Pass Block Footwork']
df_2018['Pass Blocking'] = df_2018['Pass Blocking']/2

# %%
df_2018 = df_2018[['Team', 'Name', 'Position', 'Overall', 'Speed',
       'Strength', 'Agility', 'Acceleration', 'Awareness', 'Trucking', 'Ball Carrier Vision', 'Stiff Arm', 'Spin Move',
       'Juke Move', 'Carrying', 'Catching', 'Route Running',
       'Catch In Traffic', 'Release', 'Jumping',
       'Throw Power', 'Throw Accuracy', 'Short Accuracy', 'Middle Accuracy',
       'Deep Accuracy', 'Throw On The Run', 'Play Action',
       'Kick Power', 'Kick Accuracy', 'Impact Blocking', 'Run Blocking',
       'Pass Blocking', 'Kick Return', 'Toughness', 'Stamina', 'Injury']]
df_2018
# Out:
#          Team               Name Position  Overall  Speed  Strength  Agility  \
# 0       49ers      Jeremy Zuttah        C       82     69        87       62
# 1       49ers         Tim Barnes        C       71     65        84       64
# 2       49ers     Daniel Kilgore        C       71     61        89       57
# 3       49ers   Rashard Robinson       CB       76     93        65       86
# 4       49ers    K'Waun Williams       CB       74     88        48       92
# ...       ...                ...      ...      ...    ...       ...      ...
# 2337  Vikings      Jarius Wright       WR       73     91        42       93
# 2338  Vikings       Rodney Adams       WR       68     91        51       91
# 2339  Vikings        Stacy Coley       WR       66     91        55       89
# 2340  Vikings  Moritz Boehringer       WR       62     89        70       87
# 2341  Vikings       R.J. Shelton       WR       61     84        63       88
#
# ...

# %%
df_2017
# Out:
#          Team                   Name Position  Overall  Speed  Strength  \
# 0       49ers         Daniel Kilgore        C       71     60        89
# 1       49ers          Marcus Martin        C       65     64        82
# 2       49ers         Tramaine Brock       CB       81     88        59
# 3       49ers          Kenneth Acker       CB       75     88        50
# 4       49ers         Dontae Johnson       CB       75     89        53
# ...       ...                    ...      ...      ...    ...       ...
# 2358  Vikings          Jarius Wright       WR       75     90        42
# 2359  Vikings        Charles Johnson       WR       74     91        63
# 2360  Vikings  Cordarrelle Patterson       WR       70     92        65
# 2361  Vikings           Adam Thielen       WR       69     87        53
# 2362  Vikings      Moritz Boehringer       WR       62     89        70
#
#       Agility  Acceleration  Awareness  Trucking  ...  Play Action  \
# ...

# %%
df_2019 = df_2019.rename(columns={'Throw Accuracy Short':'Short Accuracy',
                                  'Throw Accuracy Mid':'Middle Accuracy',
                                  'Throw Accuracy Deep':'Deep Accuracy',
                                  'Throw on the Run':'Throw On The Run',
                                  'Catch':'Catching',                                  
                                  'Pass Block':'Pass Blocking',
                                  'Run Block':'Run Blocking',              
                                  'Medium Route Running':'Route Running',                                   
                                  'Catch in Traffic':'Catch In Traffic'                                  
                                 })

# %%
df_2019['Throw Accuracy'] = df_2019['Deep Accuracy']+df_2019['Middle Accuracy']+df_2019['Short Accuracy']
df_2019['Throw Accuracy'] = df_2019['Throw Accuracy']/3

# %%
df_2019 = df_2019[['Team', 'Name', 'Position', 'Overall', 'Speed',
       'Strength', 'Agility', 'Acceleration', 'Awareness', 'Trucking', 'Ball Carrier Vision', 'Stiff Arm', 'Spin Move',
       'Juke Move', 'Carrying', 'Catching', 'Route Running',
       'Catch In Traffic', 'Release', 'Jumping',
       'Throw Power', 'Throw Accuracy', 'Short Accuracy', 'Middle Accuracy',
       'Deep Accuracy', 'Throw On The Run', 'Play Action',
       'Kick Power', 'Kick Accuracy', 'Impact Blocking', 'Run Blocking',
       'Pass Blocking', 'Kick Return', 'Toughness', 'Stamina', 'Injury']]
df_2019
# Out:
#             Team            Name Position  Overall  Speed  Strength  Agility  \
# 0       Patriots       Tom Brady       QB       99     61        64       67
# 1       Patriots  Rob Gronkowski       TE       99     83        85       85
# 2       Steelers   Antonio Brown       WR       99     92        54       98
# 3        Broncos      Von Miller     LOLB       99     87        84       90
# 4        Packers   Aaron Rodgers       QB       99     79        58       82
# ...          ...             ...      ...      ...    ...       ...      ...
# 2363     Packers  Hunter Bradley       TE       39     80        66       68
# 2364    Patriots     Joe Cardona       TE       38     75        82       72
# 2365  Buccaneers     Drew Ferris       TE       38     67        49       66
# 2366       Colts     Luke Rhodes       TE       36     80        83       77
# 2367      Saints       Zach Wood       TE       35     67        75       72
#
# ...

# %%
df_2020 = df_2020.rename(columns={'spin move rating':'Spin Move',
                                  'throw accuracy short rating':'Short Accuracy',
                                  'throw accuracy mid rating':'Middle Accuracy',
                                  'throw accuracy deep rating':'Deep Accuracy',
                                  'throw on the run rating':'Throw On The Run',
                                  'juke move rating':'Juke Move',                                  
                                  'agility rating':'Agility',
                                  'kick return rating':'Kick Return',              
                                  'stamina rating':'Stamina',                                   
                                  'catch in traffic rating':'Catch In Traffic',
                                  'trucking rating':'Trucking',
                                  'throw power rating':'Throw Power',
                                  'speed rating':'Speed',
                                  'carrying rating':'Carrying',
                                  'release rating':'Release',
                                  'impact blocking rating':'Impact Blocking',                                  
                                  'kick accuracy rating':'Kick Accuracy',
                                  'position':'Position',              
                                  'injury rating':'Injury',                                   
                                  'catching rating':'Catching',
                                  'awareness rating':'Awareness',
                                  'b c vision rating':'Ball Carrier Vision',
                                  'ovr rating':'Overall',                                  
                                  'play action rating':'Play Action',
                                  'jumping rating':'Jumping',     
                                  'toughness rating':'Toughness',              
                                  'stiff arm rating':'Stiff Arm',                                   
                                  'kick power rating':'Kick Power',
                                  'strength rating':'Strength',
                                  'pass block rating':'Pass Blocking',
                                  'acceleration rating':'Acceleration',                                  
                                  'medium route running rating':'Route Running',
                                  'run block rating':'Run Blocking',   
                                 })

# %%
df_2020['Throw Accuracy'] = df_2020['Deep Accuracy']+df_2020['Middle Accuracy']+df_2020['Short Accuracy']
df_2020['Throw Accuracy'] = df_2020['Throw Accuracy']/3

# %%
df_2020 = df_2020[['Team', 'Name', 'Position', 'Overall', 'Speed',
       'Strength', 'Agility', 'Acceleration', 'Awareness', 'Trucking', 'Ball Carrier Vision', 'Stiff Arm', 'Spin Move',
       'Juke Move', 'Carrying', 'Catching', 'Route Running',
       'Catch In Traffic', 'Release', 'Jumping',
       'Throw Power', 'Throw Accuracy', 'Short Accuracy', 'Middle Accuracy',
       'Deep Accuracy', 'Throw On The Run', 'Play Action',
       'Kick Power', 'Kick Accuracy', 'Impact Blocking', 'Run Blocking',
       'Pass Blocking', 'Kick Return', 'Toughness', 'Stamina', 'Injury']]
df_2020
# Out:
#      Team             Name Position  Overall  Speed  Strength  Agility  \
# 0     LAR     Aaron Donald       RE       99     83        99       86
# 1     HOU  DeAndre Hopkins       WR       99     92        78       92
# 2     CHI      Khalil Mack     LOLB       99     87        89       88
# 3     SEA     Bobby Wagner      MLB       99     88        81       85
# 4      LV    Antonio Brown       WR       98     92        55       98
# ...   ...              ...      ...      ...    ...       ...      ...
# 2339   NE      Joe Cardona       TE       38     75        82       72
# 2340  MIN   Austin Cutting       TE       38     67        71       77
# 2341  PIT  Kameron Canaday       TE       37     67        64       61
# 2342  IND      Luke Rhodes       TE       37     80        81       79
# 2343   NO        Zach Wood       TE       36     67        75       70
#
#       Acceleration  Awareness  Trucking  ...  Play Action  Kick Power  \
# ...

# %%
df_2021 = df_2021.rename(columns={'Throw Accuracy Short':'Short Accuracy',
                                  'Throw Accuracy Mid':'Middle Accuracy',
                                  'Throw Accuracy Deep':'Deep Accuracy',
                                  'Overall Rating':'Overall',                                  
                                  'Full Name':'Name',             
                                  'Medium Route Running':'Route Running',                                   
                                  'Catch in Traffic':'Catch In Traffic'                                  
                                 })

# %%
df_2021['Throw Accuracy'] = df_2021['Deep Accuracy']+df_2021['Middle Accuracy']+df_2021['Short Accuracy']
df_2021['Throw Accuracy'] = df_2021['Throw Accuracy']/3

# %%
df_2021 = df_2021[['Team', 'Name', 'Position', 'Overall', 'Speed',
       'Strength', 'Agility', 'Acceleration', 'Awareness', 'Trucking', 'Ball Carrier Vision', 'Stiff Arm', 'Spin Move',
       'Juke Move', 'Carrying', 'Catching', 'Route Running',
       'Catch In Traffic', 'Release', 'Jumping',
       'Throw Power', 'Throw Accuracy', 'Short Accuracy', 'Middle Accuracy',
       'Deep Accuracy', 'Throw On The Run', 'Play Action',
       'Kick Power', 'Kick Accuracy', 'Impact Blocking', 'Run Blocking',
       'Pass Blocking', 'Kick Return', 'Toughness', 'Stamina', 'Injury']]
df_2021
# Out:
#             Team                 Name Position  Overall  Speed  Strength  \
# 0           Rams         Aaron Donald       RE       99     82        99
# 1       Patriots      Stephon Gilmore       CB       99     92        70
# 2       Panthers  Christian McCaffrey       HB       99     92        72
# 3         Chiefs      Patrick Mahomes       QB       99     81        69
# 4         Saints       Michael Thomas       WR       99     89        77
# ...          ...                  ...      ...      ...    ...       ...
# 2288    Steelers      Kameron Canaday       TE       26     66        64
# 2289     Jaguars          Matt Orzech       TE       25     77        73
# 2290       Colts          Luke Rhodes       TE       24     80        81
# 2291     Raiders           Trent Sieg       TE       24     62        69
# 2292  Buccaneers          Zach Triner       TE       23     77        74
#
#       Agility  Acceleration  Awareness  Trucking  ...  Play Action  \
# ...

# %%
df_2017['PlayerID']= df_2017['Name'] + '-2017'
df_2017['Year']= '2017'
df_2017
# Out:
#          Team                   Name Position  Overall  Speed  Strength  \
# 0       49ers         Daniel Kilgore        C       71     60        89
# 1       49ers          Marcus Martin        C       65     64        82
# 2       49ers         Tramaine Brock       CB       81     88        59
# 3       49ers          Kenneth Acker       CB       75     88        50
# 4       49ers         Dontae Johnson       CB       75     89        53
# ...       ...                    ...      ...      ...    ...       ...
# 2358  Vikings          Jarius Wright       WR       75     90        42
# 2359  Vikings        Charles Johnson       WR       74     91        63
# 2360  Vikings  Cordarrelle Patterson       WR       70     92        65
# 2361  Vikings           Adam Thielen       WR       69     87        53
# 2362  Vikings      Moritz Boehringer       WR       62     89        70
#
#       Agility  Acceleration  Awareness  Trucking  ...  Kick Accuracy  \
# ...

# %%
df_2018['PlayerID']= df_2018['Name'] + '-2018'
df_2018['Year']= '2018'
df_2018
# Out:
#          Team               Name Position  Overall  Speed  Strength  Agility  \
# 0       49ers      Jeremy Zuttah        C       82     69        87       62
# 1       49ers         Tim Barnes        C       71     65        84       64
# 2       49ers     Daniel Kilgore        C       71     61        89       57
# 3       49ers   Rashard Robinson       CB       76     93        65       86
# 4       49ers    K'Waun Williams       CB       74     88        48       92
# ...       ...                ...      ...      ...    ...       ...      ...
# 2337  Vikings      Jarius Wright       WR       73     91        42       93
# 2338  Vikings       Rodney Adams       WR       68     91        51       91
# 2339  Vikings        Stacy Coley       WR       66     91        55       89
# 2340  Vikings  Moritz Boehringer       WR       62     89        70       87
# 2341  Vikings       R.J. Shelton       WR       61     84        63       88
#
# ...

# %%
df_2019['PlayerID']= df_2019['Name'] + '-2019'
df_2019['Year']= '2019'
df_2019
# Out:
#             Team            Name Position  Overall  Speed  Strength  Agility  \
# 0       Patriots       Tom Brady       QB       99     61        64       67
# 1       Patriots  Rob Gronkowski       TE       99     83        85       85
# 2       Steelers   Antonio Brown       WR       99     92        54       98
# 3        Broncos      Von Miller     LOLB       99     87        84       90
# 4        Packers   Aaron Rodgers       QB       99     79        58       82
# ...          ...             ...      ...      ...    ...       ...      ...
# 2363     Packers  Hunter Bradley       TE       39     80        66       68
# 2364    Patriots     Joe Cardona       TE       38     75        82       72
# 2365  Buccaneers     Drew Ferris       TE       38     67        49       66
# 2366       Colts     Luke Rhodes       TE       36     80        83       77
# 2367      Saints       Zach Wood       TE       35     67        75       72
#
# ...

# %%
df_2020['PlayerID']= df_2020['Name'] + '-2020'
df_2020['Year']= '2020'
df_2020
# Out:
#      Team             Name Position  Overall  Speed  Strength  Agility  \
# 0     LAR     Aaron Donald       RE       99     83        99       86
# 1     HOU  DeAndre Hopkins       WR       99     92        78       92
# 2     CHI      Khalil Mack     LOLB       99     87        89       88
# 3     SEA     Bobby Wagner      MLB       99     88        81       85
# 4      LV    Antonio Brown       WR       98     92        55       98
# ...   ...              ...      ...      ...    ...       ...      ...
# 2339   NE      Joe Cardona       TE       38     75        82       72
# 2340  MIN   Austin Cutting       TE       38     67        71       77
# 2341  PIT  Kameron Canaday       TE       37     67        64       61
# 2342  IND      Luke Rhodes       TE       37     80        81       79
# 2343   NO        Zach Wood       TE       36     67        75       70
#
#       Acceleration  Awareness  Trucking  ...  Kick Accuracy  Impact Blocking  \
# ...

# %%
df_2021['PlayerID']= df_2021['Name'] + '-2021'
df_2021['Year']= '2021'
df_2021
# Out:
#             Team                 Name Position  Overall  Speed  Strength  \
# 0           Rams         Aaron Donald       RE       99     82        99
# 1       Patriots      Stephon Gilmore       CB       99     92        70
# 2       Panthers  Christian McCaffrey       HB       99     92        72
# 3         Chiefs      Patrick Mahomes       QB       99     81        69
# 4         Saints       Michael Thomas       WR       99     89        77
# ...          ...                  ...      ...      ...    ...       ...
# 2288    Steelers      Kameron Canaday       TE       26     66        64
# 2289     Jaguars          Matt Orzech       TE       25     77        73
# 2290       Colts          Luke Rhodes       TE       24     80        81
# 2291     Raiders           Trent Sieg       TE       24     62        69
# 2292  Buccaneers          Zach Triner       TE       23     77        74
#
#       Agility  Acceleration  Awareness  Trucking  ...  Kick Accuracy  \
# ...

# %%
df = pd.merge(df_2017,df_2020,on='PlayerID',how='left')

# %%
frames = [df_2017, df_2018, df_2019, df_2020, df_2021]

df = pd.concat(frames)

# %%
df
# Out:
#             Team             Name Position  Overall  Speed  Strength  Agility  \
# 0          49ers   Daniel Kilgore        C       71     60        89       57
# 1          49ers    Marcus Martin        C       65     64        82       66
# 2          49ers   Tramaine Brock       CB       81     88        59       87
# 3          49ers    Kenneth Acker       CB       75     88        50       92
# 4          49ers   Dontae Johnson       CB       75     89        53       91
# ...          ...              ...      ...      ...    ...       ...      ...
# 2288    Steelers  Kameron Canaday       TE       26     66        64       61
# 2289     Jaguars      Matt Orzech       TE       25     77        73       80
# 2290       Colts      Luke Rhodes       TE       24     80        81       79
# 2291     Raiders       Trent Sieg       TE       24     62        69       79
# 2292  Buccaneers      Zach Triner       TE       23     77        74       69
#
# ...

# %%
_2016 = pd.read_csv('https://raw.githubusercontent.com/fantasydatapros/data/master/yearly/2016.csv').iloc[:, 1:]
_2017 = pd.read_csv('https://raw.githubusercontent.com/fantasydatapros/data/master/yearly/2017.csv').iloc[:, 1:]
_2018 = pd.read_csv('https://raw.githubusercontent.com/fantasydatapros/data/master/yearly/2018.csv').iloc[:, 1:]
_2019 = pd.read_csv('https://raw.githubusercontent.com/fantasydatapros/data/master/yearly/2019.csv').iloc[:, 1:]
_2020 = pd.read_csv('https://raw.githubusercontent.com/fantasydatapros/data/master/yearly/2020.csv')

# %%
qb_df_2019 = df_2019.loc[df_2019['Position'] == 'QB']
qb_df_2019.head(40)
# Out:
#             Team                Name Position  Overall  Speed  Strength  \
# 0       Patriots           Tom Brady       QB       99     61        64
# 4        Packers       Aaron Rodgers       QB       99     79        58
# 54      Seahawks      Russell Wilson       QB       92     86        59
# 66        Saints          Drew Brees       QB       91     69        53
# 106      Falcons           Matt Ryan       QB       89     72        63
# 115     Steelers  Ben Roethlisberger       QB       88     72        82
# 127     Panthers          Cam Newton       QB       88     85        81
# 140        Colts         Andrew Luck       QB       87     83        74
# 146     Chargers       Philip Rivers       QB       87     62        62
# 178       Eagles        Carson Wentz       QB       86     82        72
# 206        Lions    Matthew Stafford       QB       85     75        67
# 246     Redskins          Alex Smith       QB       84     78        63
# ...

# %%
PassingLeaders = _2020.sort_values(by='PassingYds', ascending=False)
PassingLeaders.head(10)
# Out:
#              Player   Tm Pos   Age   G  GS  Tgt  Rec  PassingYds  PassingTD  \
# 10   Deshaun Watson  HOU  QB  25.0  16  16    0    0        4823         33
# 9   Patrick Mahomes  KAN  QB  25.0  15  15    2    0        4740         38
# 24        Tom Brady  TAM  QB  43.0  16  16    0    0        4633         40
# 78        Matt Ryan  ATL  QB  35.0  16  16    0    0        4581         26
# 6        Josh Allen  BUF  QB  24.0  16  16    1    1        4544         37
# 28   Justin Herbert  LAC  QB  22.0  15  15    0    0        4336         31
# 7     Aaron Rodgers  GNB  QB  37.0  16  16    1    1        4299         48
# 44     Kirk Cousins  MIN  QB  32.0  16  16    0    0        4265         35
# 15   Russell Wilson  SEA  QB  32.0  16  16    0    0        4212         40
# 86    Philip Rivers  IND  QB  39.0  16  16    0    0        4169         24
#
#     PassingAtt  RushingYds  RushingTD  RushingAtt  ReceivingYds  ReceivingTD  \
# ...

# %%
OL_2019 = ['LT','LG','C','RG','RT']
OL_2019 = df_2019.loc[df_2019['Position'].isin(OL_2019)]
# OL_2019 = OL_2019.head(200)
OL_2019.groupby('Team')['Overall'].describe()
# Out:
#             count       mean        std   min    25%   50%    75%   max
# Team
# 49ers        11.0  72.000000   8.111720  63.0  66.00  70.0  75.00  90.0
# Bears        12.0  70.583333   6.487167  62.0  66.25  70.0  75.25  81.0
# Bengals      14.0  67.500000   6.085923  58.0  63.25  66.0  70.00  79.0
# Bills        12.0  69.333333   4.559373  62.0  65.75  69.0  73.00  77.0
# Broncos      13.0  70.307692   6.459936  64.0  66.00  68.0  74.00  82.0
# Browns       15.0  69.466667   9.356943  57.0  64.00  67.0  72.50  89.0
# Buccaneers   13.0  70.538462   7.964666  60.0  65.00  68.0  73.00  88.0
# Cardinals    15.0  68.066667   6.474860  60.0  63.50  67.0  73.50  80.0
# Chargers     14.0  67.428571   6.858059  61.0  62.25  64.0  73.50  80.0
# Chiefs       11.0  68.818182   7.639610  59.0  65.00  66.0  74.50  81.0
# Colts        14.0  71.642857   7.131805  63.0  65.25  71.5  75.75  84.0
# Cowboys      12.0  73.583333  13.983486  60.0  63.75  66.5  80.75  96.0
# ...

# %%
# OL_2018 = df_2018[['Name','Team','Position','Overall']]
# OL_2018= OL_2018.groupby(['Team'],as_index=False).apply(lambda x: x.nlargest(5, 'Overall'))
# OL_2018.reset_index(inplace=True)

# print(OL_2018)

# %%
OL=OL_2019.sort_values('Overall', ascending=False).groupby('Team').head(5).sort_values(['Position', 'Overall'], ascending=False)
OL_2019 = OL.groupby('Team')['Overall'].describe()

OL_2019 = OL_2019.reset_index()
OL_2019 = OL_2019.set_index('Team')
OL_2019 = OL_2019.reset_index()
OL_2019
# Out:
#           Team  count  mean        std   min   25%   50%   75%   max
# 0        49ers    5.0  78.6   7.469940  72.0  72.0  78.0  81.0  90.0
# 1        Bears    5.0  76.8   4.147288  71.0  74.0  79.0  79.0  81.0
# 2      Bengals    5.0  74.2   4.086563  70.0  70.0  75.0  77.0  79.0
# 3        Bills    5.0  73.8   1.923538  72.0  73.0  73.0  74.0  77.0
# 4      Broncos    5.0  77.0   5.431390  69.0  74.0  79.0  81.0  82.0
# 5       Browns    5.0  80.0   8.485281  71.0  74.0  77.0  89.0  89.0
# 6   Buccaneers    5.0  78.4   6.503845  72.0  73.0  78.0  81.0  88.0
# 7    Cardinals    5.0  75.8   2.683282  73.0  74.0  76.0  76.0  80.0
# 8     Chargers    5.0  75.8   3.193744  72.0  74.0  75.0  78.0  80.0
# 9       Chiefs    5.0  75.4   5.683309  67.0  73.0  76.0  80.0  81.0
# 10       Colts    5.0  79.2   4.086563  75.0  76.0  78.0  83.0  84.0
# 11     Cowboys    5.0  87.0  11.958261  72.0  76.0  95.0  96.0  96.0
# 12    Dolphins    5.0  77.8   8.408329  67.0  73.0  77.0  84.0  88.0
# ...

# %%
OL_2019['OLrank'] = OL_2019['mean'].rank(method='first', ascending=False)
OL_2019 = OL_2019[['Team','mean','OLrank']]

OL_2019 = OL_2019.sort_values(by='OLrank')
OL_2019 = OL_2019.reset_index()
OL_2019 = OL_2019[['Team','mean','OLrank']]
OL_2019
# Out:
#           Team  mean  OLrank
# 0       Eagles  89.2     1.0
# 1      Cowboys  87.0     2.0
# 2      Raiders  85.4     3.0
# 3     Steelers  84.4     4.0
# 4     Patriots  82.0     5.0
# 5      Falcons  81.6     6.0
# 6     Redskins  80.6     7.0
# 7      Jaguars  80.4     8.0
# 8       Titans  80.2     9.0
# 9       Browns  80.0    10.0
# 10      Saints  80.0    11.0
# 11       Colts  79.2    12.0
# 12        Rams  79.2    13.0
# 13       Lions  79.0    14.0
# 14     Packers  79.0    15.0
# 15       49ers  78.6    16.0
# 16      Ravens  78.6    17.0
# 17  Buccaneers  78.4    18.0
# 18    Dolphins  77.8    19.0
# 19     Broncos  77.0    20.0
# 20       Bears  76.8    21.0
# 21    Panthers  76.8    22.0
# 22      Giants  76.0    23.0
# 23   Cardinals  75.8    24.0
# 24    Chargers  75.8    25.0
# 25      Chiefs  75.4    26.0
# 26     Bengals  74.2    27.0
# 27     Vikings  74.2    28.0
# 28       Bills  73.8    29.0
# 29    Seahawks  73.8    30.0
# 30        Jets  72.6    31.0
# ...

# %%
df_2019
# Out:
#             Team            Name Position  Overall  Speed  Strength  Agility  \
# 0       Patriots       Tom Brady       QB       99     61        64       67
# 1       Patriots  Rob Gronkowski       TE       99     83        85       85
# 2       Steelers   Antonio Brown       WR       99     92        54       98
# 3        Broncos      Von Miller     LOLB       99     87        84       90
# 4        Packers   Aaron Rodgers       QB       99     79        58       82
# ...          ...             ...      ...      ...    ...       ...      ...
# 2363     Packers  Hunter Bradley       TE       39     80        66       68
# 2364    Patriots     Joe Cardona       TE       38     75        82       72
# 2365  Buccaneers     Drew Ferris       TE       38     67        49       66
# 2366       Colts     Luke Rhodes       TE       36     80        83       77
# 2367      Saints       Zach Wood       TE       35     67        75       72
#
# ...

# %%
df3_merged = pd.merge(df_2019, OL_2019)

# %%
df3_merged = df3_merged[['Team','Name','Position','Overall','OLrank']]
df3_merged
# Out:
#           Team             Name Position  Overall  OLrank
# 0     Patriots        Tom Brady       QB       99     5.0
# 1     Patriots   Rob Gronkowski       TE       99     5.0
# 2     Patriots   Devin McCourty       FS       92     5.0
# 3     Patriots   Julian Edelman       WR       88     5.0
# 4     Patriots  Stephon Gilmore       CB       87     5.0
# ...        ...              ...      ...      ...     ...
# 2363      Jets      Brent Qvale       RT       64    31.0
# 2364      Jets   Doug Middleton       SS       63    31.0
# 2365      Jets       Ben Braden       LG       61    31.0
# 2366      Jets  Lawrence Thomas       FB       57    31.0
# 2367      Jets  Thomas Hennessy       TE       43    31.0
#
# [2368 rows x 5 columns]

# %%
qb_df = df3_merged.loc[df3_merged['Position'] == 'QB']

qb_df = qb_df.sort_values(by='Overall', ascending=False)
qb_df = qb_df.head(35)

# %%
plt.figure(figsize=(12, 10))
sns.regplot(qb_df['OLrank'], qb_df['Overall'])
# Out:
# C:\Users\rstro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OLrank', ylabel='Overall'>

# %%
offense_2019 = ['QB','HB','TE','WR']
offense_2019 = df3_merged.loc[df3_merged['Position'].isin(offense_2019)]

# %%
offense_2019 = offense_2019.sort_values(by='Overall', ascending=False)
offense_2019 = offense_2019.head(100)

# %%
sns.lmplot(data=offense_2019, x='OLrank', y='Overall', hue='Position', height=7)

# %%
adp_df = pd.read_csv('https://raw.githubusercontent.com/fantasydatapros/data/master/fantasypros/adp/PPR_ADP.csv', index_col=0) # set index col = 0 to set the range index as our dataframes index

adp_df = adp_df.head(225)

adp_df = adp_df.rename(columns={'PLAYER':'Name'})
adp_df
# Out:
#                     Name POS    AVG
# 0    Christian McCaffrey  RB    1.0
# 1         Saquon Barkley  RB    2.0
# 2        Ezekiel Elliott  RB    3.5
# 3         Michael Thomas  WR    4.0
# 4            Dalvin Cook  RB    5.0
# ..                   ...  ..    ...
# 211        Bryan Edwards  WR  219.0
# 248      Lynn Bowden Jr.  RB  219.0
# 192       Chris Thompson  RB  219.0
# 213      Giovani Bernard  RB  220.0
# 214       Chase Claypool  WR  221.0
#
# [225 rows x 3 columns]

# %%
df1 = pd.merge(df3_merged, adp_df)

# %%
df1 = df1.sort_values(by='Overall', ascending=False)
offense_2019 = ['QB','HB','TE','WR']
df1 = df1.loc[df1['Position'].isin(offense_2019)]

# %%
sns.lmplot(data=df1, x='OLrank', y='Overall', hue='Position', height=7)

# %%
df1.groupby('Team')['AVG'].describe()
# Out:
#             count        mean         std    min      25%     50%      75%  \
# Team
# 49ers         4.0   82.375000   59.617356   20.5   47.125   74.50  109.750
# Bears         4.0   83.500000   41.321907   29.0   72.875   87.75   98.375
# Bengals       5.0  110.200000   87.413243   10.0   69.500   69.50  182.000
# Bills         2.0  135.250000   70.357125   85.5  110.375  135.25  160.125
# Broncos       2.0   74.250000   42.072853   44.5   59.375   74.25   89.125
# Browns        3.0   74.166667   58.779957   16.5   44.250   72.00  103.000
# Buccaneers    5.0   96.900000   80.690303   18.0   26.500   83.00  152.500
# Cardinals     4.0  117.000000   67.396835   38.5   77.500  117.50  157.000
# Chargers      6.0  102.000000   65.617833   12.0   55.750  108.25  154.000
# Chiefs        4.0   61.875000   66.491071   14.0   16.250   38.50   84.125
# Colts         5.0  118.600000   39.702645   58.5   98.000  140.50  142.500
# ...

# %%
#Only get the offensive line positions
OL_2017 = ['LT','LG','C','RG','RT']
OL_2017 = df_2017.loc[df_2017['Position'].isin(OL_2017)]

#Only grab the top 5 overall offensive linemen from each team
OL=OL_2017.sort_values('Overall', ascending=False).groupby('Team').head(5).sort_values(['Position', 'Overall'], ascending=False)
OL_2017 = OL.groupby('Team')['Overall'].describe()
OL_2017 = OL_2017.reset_index()
OL_2017 = OL_2017.set_index('Team')
OL_2017 = OL_2017.reset_index()

#Get a team rank for OL
OL_2017['OLrank'] = OL_2017['mean'].rank(method='first', ascending=False)
OL_2017 = OL_2017[['Team','mean','OLrank']]
OL_2017 = OL_2017.sort_values(by='OLrank')
OL_2017 = OL_2017.reset_index()
OL_2017 = OL_2017[['Team','mean','OLrank']]

#Merge madden ratings with O-line rating
df3_merged_2017 = pd.merge(df_2017, OL_2017)


#Get only skill positions
offense_2017 = ['QB','HB','TE','WR']
offense_2017 = df3_merged_2017.loc[df3_merged_2017['Position'].isin(offense_2017)]
offense_2017 = offense_2017.rename(columns={'mean':'OL Rating'})
offense_2017
# Out:
#          Team                   Name Position  Overall  Speed  Strength  \
# 16      49ers            Carlos Hyde       HB       81     86        78
# 17      49ers          Shaun Draughn       HB       73     82        72
# 18      49ers             Mike Davis       HB       71     88        69
# 19      49ers          DuJuan Harris       HB       70     88        60
# 20      49ers          Kelvin Taylor       HB       67     87        69
# ...       ...                    ...      ...      ...    ...       ...
# 2358  Vikings          Jarius Wright       WR       75     90        42
# 2359  Vikings        Charles Johnson       WR       74     91        63
# 2360  Vikings  Cordarrelle Patterson       WR       70     92        65
# 2361  Vikings           Adam Thielen       WR       69     87        53
# 2362  Vikings      Moritz Boehringer       WR       62     89        70
#
#       Agility  Acceleration  Awareness  Trucking  ...  Run Blocking  \
# ...

# %%
#Only get the offensive line positions
OL_2018 = ['LT','LG','C','RG','RT']
OL_2018 = df_2018.loc[df_2019['Position'].isin(OL_2018)]

#Only grab the top 5 overall offensive linemen from each team
OL=OL_2018.sort_values('Overall', ascending=False).groupby('Team').head(5).sort_values(['Position', 'Overall'], ascending=False)
OL_2018 = OL.groupby('Team')['Overall'].describe()
OL_2018 = OL_2018.reset_index()
OL_2018 = OL_2018.set_index('Team')
OL_2018 = OL_2018.reset_index()

#Get a team rank for OL
OL_2018['OLrank'] = OL_2018['mean'].rank(method='first', ascending=False)
OL_2018 = OL_2018[['Team','mean','OLrank']]
OL_2018 = OL_2018.sort_values(by='OLrank')
OL_2018 = OL_2018.reset_index()
OL_2018 = OL_2018[['Team','mean','OLrank']]

#Merge madden ratings with O-line rating
df3_merged_2018 = pd.merge(df_2018, OL_2018)


#Get only skill positions
offense_2018 = ['QB','HB','TE','WR']
offense_2018 = df3_merged_2018.loc[df3_merged_2018['Position'].isin(offense_2018)]
offense_2018 = offense_2018.rename(columns={'mean':'OL Rating'})
offense_2018
# Out:
#          Team               Name Position  Overall  Speed  Strength  Agility  \
# 20      49ers        Carlos Hyde       HB       83     88        81       91
# 21      49ers      Tim Hightower       HB       80     87        76       86
# 22      49ers       Joe Williams       HB       72     92        72       91
# 23      49ers        Kapri Bibbs       HB       68     85        73       86
# 24      49ers     Raheem Mostert       HB       60     93        67       87
# ...       ...                ...      ...      ...    ...       ...      ...
# 2337  Vikings      Jarius Wright       WR       73     91        42       93
# 2338  Vikings       Rodney Adams       WR       68     91        51       91
# 2339  Vikings        Stacy Coley       WR       66     91        55       89
# 2340  Vikings  Moritz Boehringer       WR       62     89        70       87
# 2341  Vikings       R.J. Shelton       WR       61     84        63       88
#
# ...

# %%
#Only get the offensive line positions
OL_2019 = ['LT','LG','C','RG','RT']
OL_2019 = df_2019.loc[df_2019['Position'].isin(OL_2019)]

#Only grab the top 5 overall offensive linemen from each team
OL=OL_2019.sort_values('Overall', ascending=False).groupby('Team').head(5).sort_values(['Position', 'Overall'], ascending=False)
OL_2019 = OL.groupby('Team')['Overall'].describe()
OL_2019 = OL_2019.reset_index()
OL_2019 = OL_2019.set_index('Team')
OL_2019 = OL_2019.reset_index()

#Get a team rank for OL
OL_2019['OLrank'] = OL_2019['mean'].rank(method='first', ascending=False)
OL_2019 = OL_2019[['Team','mean','OLrank']]
OL_2019 = OL_2019.sort_values(by='OLrank')
OL_2019 = OL_2019.reset_index()
OL_2019 = OL_2019[['Team','mean','OLrank']]

#Merge madden ratings with O-line rating
df3_merged_2019 = pd.merge(df_2019, OL_2019)


#Get only skill positions
offense_2019 = ['QB','HB','TE','WR']
offense_2019 = df3_merged_2019.loc[df3_merged_2019['Position'].isin(offense_2019)]
offense_2019 = offense_2019.rename(columns={'mean':'OL Rating'})
offense_2019
# Out:
#           Team                    Name Position  Overall  Speed  Strength  \
# 0     Patriots               Tom Brady       QB       99     61        64
# 1     Patriots          Rob Gronkowski       TE       99     83        85
# 3     Patriots          Julian Edelman       WR       88     85        68
# 13    Patriots             Chris Hogan       WR       83     88        72
# 15    Patriots             James White       HB       83     89        68
# ...        ...                     ...      ...      ...    ...       ...
# 2345      Jets  Christopher Herndon IV       TE       69     80        71
# 2348      Jets             Devin Smith       WR       69     91        62
# 2349      Jets         Lucky Whitehead       WR       69     93        63
# 2362      Jets           Charone Peake       WR       65     93        66
# 2367      Jets         Thomas Hennessy       TE       43     71        64
#
#       Agility  Acceleration  Awareness  Trucking  ...  Run Blocking  \
# ...

# %%
#Only get the offensive line positions
OL_2020 = ['LT','LG','C','RG','RT']
OL_2020 = df_2020.loc[df_2020['Position'].isin(OL_2020)]

#Only grab the top 5 overall offensive linemen from each team
OL=OL_2020.sort_values('Overall', ascending=False).groupby('Team').head(5).sort_values(['Position', 'Overall'], ascending=False)
OL_2020 = OL.groupby('Team')['Overall'].describe()
OL_2020 = OL_2020.reset_index()
OL_2020 = OL_2020.set_index('Team')
OL_2020 = OL_2020.reset_index()

#Get a team rank for OL
OL_2020['OLrank'] = OL_2020['mean'].rank(method='first', ascending=False)
OL_2020 = OL_2020[['Team','mean','OLrank']]
OL_2020 = OL_2020.sort_values(by='OLrank')
OL_2020 = OL_2020.reset_index()
OL_2020 = OL_2020[['Team','mean','OLrank']]

#Merge madden ratings with O-line rating
df3_merged_2020 = pd.merge(df_2020, OL_2020)


#Get only skill positions
offense_2020 = ['QB','HB','TE','WR']
offense_2020 = df3_merged_2020.loc[df3_merged_2020['Position'].isin(offense_2020)]
offense_2020 = offense_2020.rename(columns={'mean':'OL Rating'})
offense_2020
# Out:
#      Team            Name Position  Overall  Speed  Strength  Agility  \
# 1     LAR  Todd Gurley II       HB       97     92        75       95
# 3     LAR   Brandin Cooks       WR       87     95        54       95
# 5     LAR    Robert Woods       WR       87     91        60       88
# 10    LAR     Cooper Kupp       WR       84     88        65       94
# 11    LAR      Jared Goff       QB       83     78        64       72
# ...   ...             ...      ...      ...    ...       ...      ...
# 2311  MIA   Durham Smythe       TE       67     79        75       78
# 2315  MIA    Myles Gaskin       HB       65     87        69       82
# 2340  MIA  Kenneth Farrow       HB       53     86        74       83
# 2342  MIA     Jake Rudock       QB       51     76        56       75
# 2343  MIA     John Denney       TE       47     66        76       67
#
#       Acceleration  Awareness  Trucking  ...  Run Blocking  Pass Blocking  \
# ...

# %%
#Only get the offensive line positions
OL_2020 = ['LT','LG','C','RG','RT']
OL_2020 = df_2020.loc[df_2020['Position'].isin(OL_2020)]

#Only grab the top 5 overall offensive linemen from each team
OL=OL_2020.sort_values('Run Blocking', ascending=False).groupby('Team').head(5).sort_values(['Position', 'Run Blocking'], ascending=False)
OL_2020 = OL.groupby('Team')['Run Blocking'].describe()
OL_2020 = OL_2020.reset_index()
OL_2020 = OL_2020.set_index('Team')
OL_2020 = OL_2020.reset_index()

#Get a team rank for OL
OL_2020['OLrank'] = OL_2020['mean'].rank(method='first', ascending=False)
OL_2020 = OL_2020[['Team','mean','OLrank']]
OL_2020 = OL_2020.sort_values(by='OLrank')
OL_2020 = OL_2020.reset_index()
OL_2020 = OL_2020[['Team','mean','OLrank']]

#Merge madden ratings with O-line rating
df3_merged_2020 = pd.merge(df_2020, OL_2020)


#Get only skill positions
offense_2020 = ['QB','HB','TE','WR']
offense_2020 = df3_merged_2020.loc[df3_merged_2020['Position'].isin(offense_2020)]
offense_2020 = offense_2020.rename(columns={'mean':'OL Rating'})


offense_2020 = offense_2020.groupby('Team')['OL Rating'].describe()
offense_2020.sort_values('mean', ascending=False)
# Out:
#       count  mean           std   min   25%   50%   75%   max
# Team
# DAL    22.0  87.2  2.909055e-14  87.2  87.2  87.2  87.2  87.2
# PHI    26.0  86.0  0.000000e+00  86.0  86.0  86.0  86.0  86.0
# NE     23.0  84.8  2.906048e-14  84.8  84.8  84.8  84.8  84.8
# PIT    19.0  83.4  1.460027e-14  83.4  83.4  83.4  83.4  83.4
# SF     22.0  83.2  2.909055e-14  83.2  83.2  83.2  83.2  83.2
# WAS    25.0  82.2  1.450389e-14  82.2  82.2  82.2  82.2  82.2
# IND    22.0  82.0  0.000000e+00  82.0  82.0  82.0  82.0  82.0
# LAR    22.0  81.2  2.909055e-14  81.2  81.2  81.2  81.2  81.2
# CHI    25.0  81.0  0.000000e+00  81.0  81.0  81.0  81.0  81.0
# CAR    24.0  80.4  2.903300e-14  80.4  80.4  80.4  80.4  80.4
# BAL    23.0  80.2  2.906048e-14  80.2  80.2  80.2  80.2  80.2
# NO     24.0  79.6  2.903300e-14  79.6  79.6  79.6  79.6  79.6
# DEN    23.0  79.4  2.906048e-14  79.4  79.4  79.4  79.4  79.4
# TEN    26.0  78.6  2.898457e-14  78.6  78.6  78.6  78.6  78.6
# ...

# %%
rb_df.head(15)
# Out:
#                 Name   Tm Pos   Age   G  GS  Tgt  Rec  PassingYds  PassingTD  \
# 0      Derrick Henry  TEN  RB  26.0  16  16   31   19           0          0
# 1       Alvin Kamara  NOR  RB  25.0  15  10  107   83           0          0
# 2        Dalvin Cook  MIN  RB  25.0  14  14   54   44           0          0
# 11   Jonathan Taylor  IND  RB  21.0  15  13   39   36           0          0
# 12       Aaron Jones  GNB  RB  26.0  14  14   63   47           0          0
# 14  David Montgomery  CHI  RB  23.0  15  14   68   54           0          0
# 17    James Robinson  JAX  RB  22.0  14  14   60   49           0          0
# 18       Josh Jacobs  LVR  RB  22.0  15  15   45   33           0          0
# 21        Nick Chubb  CLE  RB  25.0  12  12   18   16           0          0
# 30       Kareem Hunt  CLE  RB  25.0  16   5   51   38           0          0
# 32   Ezekiel Elliott  DAL  RB  25.0  15  15   71   52           0          0
# ...

# %%
#Only get the offensive line positions
OL_2021 = ['LT','LG','C','RG','RT']
OL_2021 = df_2021.loc[df_2021['Position'].isin(OL_2021)]

#Only grab the top 5 overall offensive linemen from each team
OL=OL_2021.sort_values('Overall', ascending=False).groupby('Team').head(5).sort_values(['Position', 'Overall'], ascending=False)
OL_2021 = OL.groupby('Team')['Overall'].describe()
OL_2021 = OL_2021.reset_index()
OL_2021 = OL_2021.set_index('Team')
OL_2021 = OL_2021.reset_index()

#Get a team rank for OL
OL_2021['OLrank'] = OL_2021['mean'].rank(method='first', ascending=False)
OL_2021 = OL_2021[['Team','mean','OLrank']]
OL_2021 = OL_2021.sort_values(by='OLrank')
OL_2021 = OL_2021.reset_index()
OL_2021 = OL_2021[['Team','mean','OLrank']]

#Merge madden ratings with O-line rating
df3_merged_2021 = pd.merge(df_2021, OL_2021)


#Get only skill positions
offense_2021 = ['QB','HB','TE','WR']
offense_2021 = df3_merged_2021.loc[df3_merged_2021['Position'].isin(offense_2021)]
offense_2021 = offense_2021.rename(columns={'mean':'OL Rating'})
offense_2021.sort_values('Overall', ascending=False)
# Out:
#             Team                 Name Position  Overall  Speed  Strength  \
# 282       Saints       Michael Thomas       WR       99     89        77
# 142     Panthers  Christian McCaffrey       HB       99     92        72
# 212       Chiefs      Patrick Mahomes       QB       99     81        69
# 355    Cardinals      DeAndre Hopkins       WR       98     91        77
# 567        49ers        George Kittle       TE       98     88        82
# ...          ...                  ...      ...      ...    ...       ...
# 1787    Steelers      Kameron Canaday       TE       26     66        64
# 2144     Jaguars          Matt Orzech       TE       25     77        73
# 1355       Colts          Luke Rhodes       TE       24     80        81
# 1569     Raiders           Trent Sieg       TE       24     62        69
# 1213  Buccaneers          Zach Triner       TE       23     77        74
#
#       Agility  Acceleration  Awareness  Trucking  ...  Run Blocking  \
# ...

# %%
# _2016 -  _2020
_2020 = _2020.rename(columns={'Player':'Name'})

rb_df = _2020.loc[_2020['Pos'] == 'RB']

rb_df.sort_values('FantasyPoints', ascending=False).head(59)
# Out:
#                       Name   Tm Pos   Age   G  GS  Tgt  Rec  PassingYds  \
# 0            Derrick Henry  TEN  RB  26.0  16  16   31   19           0
# 1             Alvin Kamara  NOR  RB  25.0  15  10  107   83           0
# 2              Dalvin Cook  MIN  RB  25.0  14  14   54   44           0
# 11         Jonathan Taylor  IND  RB  21.0  15  13   39   36           0
# 12             Aaron Jones  GNB  RB  26.0  14  14   63   47           0
# 14        David Montgomery  CHI  RB  23.0  15  14   68   54           0
# 17          James Robinson  JAX  RB  22.0  14  14   60   49           0
# 18             Josh Jacobs  LVR  RB  22.0  15  15   45   33           0
# 21              Nick Chubb  CLE  RB  25.0  12  12   18   16           0
# 30             Kareem Hunt  CLE  RB  25.0  16   5   51   38           0
# 32         Ezekiel Elliott  DAL  RB  25.0  15  15   71   52           0
# 34            Kenyan Drake  ARI  RB  26.0  15  13   31   25           0
# ...

# %%
merged_2020 = pd.merge(offense_2019, _2020)

df= merged_2020[merged_2020.FantasyPoints > 50]

# %%
sns.lmplot(data=df, x='OLrank', y='FantasyPoints', hue='Position', height=7)

# %%
offense_2019
# Out:
#           Team                    Name Position  Overall  Speed  Strength  \
# 0     Patriots               Tom Brady       QB       99     61        64
# 1     Patriots          Rob Gronkowski       TE       99     83        85
# 3     Patriots          Julian Edelman       WR       88     85        68
# 13    Patriots             Chris Hogan       WR       83     88        72
# 15    Patriots             James White       HB       83     89        68
# ...        ...                     ...      ...      ...    ...       ...
# 2345      Jets  Christopher Herndon IV       TE       69     80        71
# 2348      Jets             Devin Smith       WR       69     91        62
# 2349      Jets         Lucky Whitehead       WR       69     93        63
# 2362      Jets           Charone Peake       WR       65     93        66
# 2367      Jets         Thomas Hennessy       TE       43     71        64
#
#       Agility  Acceleration  Awareness  Trucking  ...  Run Blocking  \
# ...

# %%
_2020
# Out:
#                Name   Tm  Pos   Age   G  GS  Tgt  Rec  PassingYds  PassingTD  \
# 0     Derrick Henry  TEN   RB  26.0  16  16   31   19           0          0
# 1      Alvin Kamara  NOR   RB  25.0  15  10  107   83           0          0
# 2       Dalvin Cook  MIN   RB  25.0  14  14   54   44           0          0
# 3     Davante Adams  GNB   WR  28.0  14  14  149  115           0          0
# 4      Travis Kelce  KAN   TE  31.0  15  15  145  105           4          0
# ..              ...  ...  ...   ...  ..  ..  ...  ...         ...        ...
# 621   Andre Roberts  BUF   WR  32.0  15   0    5    4           0          0
# 622    Nate Sudfeld  PHI   QB  27.0   1   0    0    0          32          0
# 623  Nsimba Webster  LAR  NaN  24.0  16   0    0    0           0          0
# 624  Dede Westbrook  JAX   WR  27.0   2   0    1    1           0          0
# 625  Kendall Hinton  DEN   WR  23.0   1   0    0    0          13          0
#
# ...
